# %% [markdown]
# ## Using SLP time series variance to approximate storm tracks
# based off of Wallace et al 1988
# This algorithm has also been used by Xiasong Yang (GFDL) for extratropical storm tracks in AM5

# %%
import cartopy.crs as ccrs
import matplotlib.path as mpath
import matplotlib.pyplot as plt
import numpy as np
import scipy.signal
import xarray as xr

# parameters for setting circular cutoff for Southern Ocean plots
theta = np.linspace(0, 2*np.pi, 100)
center, radius = [0.5, 0.5], 0.5
verts = np.vstack([np.sin(theta), np.cos(theta)]).T
circle = mpath.Path(verts * radius + center)

# %%
path_slp = "/work/Katherine.Turner/tempest-extremes/odiv-251/data"
ds = xr.open_dataset(f"{path_slp}/atmos.0151010100-0155123123.slp.nc")

# %%
ds.slp
# Out:
# <xarray.DataArray 'slp' (time: 7300, lat: 180, lon: 288)>
# [378432000 values with dtype=float32]
# Coordinates:
#   * lat      (lat) float64 -89.5 -88.5 -87.5 -86.5 -85.5 ... 86.5 87.5 88.5 89.5
#   * lon      (lon) float64 0.625 1.875 3.125 4.375 ... 355.6 356.9 358.1 359.4
#   * time     (time) object 0151-01-01 06:00:00 ... 0156-01-01 00:00:00
# Attributes:
#     long_name:      sea level pressure
#     units:          pa
#     cell_methods:   time: point time: mean
#     interp_method:  conserve_order2

# %%
slp_d24 = ds.slp[4:,:,:].data  - ds.slp[:-4,:,:].data

da = xr.DataArray(
    data=slp_d24,
    dims=["time", "lat", "lon"],
    coords=dict(
        lon=(["lon"], ds.lon.data),
        lat=(["lat"], ds.lat.data),
        time=ds.time[:-4].data
    ),
    attrs=dict(
        description="24 hour change in SLP",
        units="pa",
    ),
)

# %%
slpvar_season = (1e-2*da).groupby(da.time.dt.season).var("time")

# %%
fig, axs = plt.subplots(nrows=1, ncols=2,
                       subplot_kw={'projection': ccrs.SouthPolarStereo()})
axs = axs.flatten()

slpvar_season.sel(season="DJF").plot(ax=axs[0], transform=ccrs.PlateCarree(),
                                     cbar_kwargs = {'fraction': 0.03,
                                                    'aspect': 30,
                                                    'shrink': 0.7},
                                     vmin=0, vmax=225, cmap=plt.get_cmap('viridis', 9))

slpvar_season.sel(season="JJA").plot(ax=axs[1], transform=ccrs.PlateCarree(),
                                     cbar_kwargs = {'fraction': 0.03,
                                                    'aspect': 30,
                                                    'shrink': 0.7},
                                     vmin=0, vmax=225, cmap=plt.get_cmap('viridis', 9))

for i in np.arange(2):
    axs[i].set_extent([-180, 180, -90, -30], ccrs.PlateCarree())
    axs[i].gridlines(alpha=0.7)
    axs[i].set_boundary(circle, transform=axs[i].transAxes)
    axs[i].coastlines()
    
plt.tight_layout()
plt.savefig('/work/Katherine.Turner/CM4_storms/analysis_figures/CM4_stormtracks_Wallace.png', format="png", dpi=100, bbox_inches="tight")
